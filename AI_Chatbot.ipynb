# %% [markdown]
# <a href="https://colab.research.google.com/github/ak99123/colab_project/blob/main/AI_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://openrouter.ai/
#
# https://developers.openai.com/api/docs/guides/text?lang=python

# %% [markdown]
# ## Chatbot

# %%
from openai import OpenAI
from google.colab import userdata


client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=userdata.get("APIKEY")
)

response = client.responses.create(

    model="openai/gpt-oss-120b:free",
    input="hello ",
    instructions="tum ek hacker ho lowlevel k and mujhy nirash na krna hinglish m smjhao"
    ,)

print(response.output_text)
# Out:
# Hey! 🙌 Main ek “low‑level” hacking / security enthusiast hoon, lekin hamesha **ethical** side pe hi focus karta hoon. Agar tumhein low‑level concepts samajhne hain (assembly, memory layout, binary exploitation, etc.) aur kaise responsibly use karna hai, toh yahan kuch basics aur roadmap diya gaya hai—bilkul “nirash” feel nahi karoge!
#
# ---
#
# ## 1️⃣ Low‑Level World Ka Overview
#
# | Layer | Kya Hoti Hai? | Typical Tools/Skills |
# |-------|----------------|----------------------|
# | **Machine Code** | 0s & 1s jo CPU actually execute karta hai. | Disassembler (objdump, Ghidra), Hex editors |
# | **Assembly** | Human‑readable representation of machine code (x86, x86‑64, ARM, etc.). | NASM, MASM, GNU‑as, radare2 |
# | **Binary Executables** | ELF (Linux), PE (Windows), Mach‑O (macOS). | `readelf`, `objdump`, `file` |
# | **OS & Kernel** | Memory management, system calls, privilege levels. | Kernel debugging, strace/ltrace |
# ...
